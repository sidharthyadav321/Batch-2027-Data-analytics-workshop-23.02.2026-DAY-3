# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamaddheshiya/Batch-2027-Data-Analytics-Workshop-19.02.2026-to-17.03.2026/blob/main/CalculateMeanMedianModeVarianceStandardDeviation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
import numpy as np

numbers = [10, 20, 30, 40, 50, 20]

mean = statistics.mean(numbers)
median = statistics.median(numbers)
mode = statistics.mode(numbers)
variance = statistics.variance(numbers)
std_dev = statistics.stdev(numbers)

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 28.333333333333332
# Median: 25.0
# Mode: 20
# Variance: 216.66666666666666
# Standard Deviation: 14.719601443879744
