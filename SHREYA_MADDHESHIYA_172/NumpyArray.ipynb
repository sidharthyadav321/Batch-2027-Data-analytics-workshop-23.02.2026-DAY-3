# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyamaddheshiya/Batch-2027-Data-Analytics-Workshop-19.02.2026-to-17.03.2026/blob/main/NumpyArray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
import numpy as np

numbers = [10, 20, 30, 40, 50, 20]

mean = statistics.mean(numbers)
median = statistics.median(numbers)
mode = statistics.mode(numbers)
variance = statistics.variance(numbers)
std_dev = statistics.stdev(numbers)

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 28.333333333333332
# Median: 25.0
# Mode: 20
# Variance: 216.66666666666666
# Standard Deviation: 14.719601443879744

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6])

# Sum and Mean
print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))

# Max and Min
print("Maximum:", np.max(arr))
print("Minimum:", np.min(arr))

# Reshape (2x3 matrix)
reshaped = arr.reshape(2, 3)
print("Reshaped Array:\n", reshaped)

# Element-wise multiplication
result = arr * 2
print("Element-wise Multiplication:\n", result)
# Out:
# Sum: 21
# Mean: 3.5
# Maximum: 6
# Minimum: 1
# Reshaped Array:
#  [[1 2 3]
#  [4 5 6]]
# Element-wise Multiplication:
#  [ 2  4  6  8 10 12]
